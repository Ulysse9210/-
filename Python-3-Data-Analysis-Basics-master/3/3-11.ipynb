# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(45)

# %%
y
# Out:
# array([0.60588448, 0.3425955 , 0.89578225, 0.87914074, 0.27075391,
#        0.26312379, 0.40768959, 0.2510613 , 0.69934084, 0.16382981,
#        0.49924267, 0.60864391, 0.81083753, 0.01673799, 0.76929585,
#        0.52107274, 0.56526117, 0.00325911, 0.73862911, 0.66758769,
#        0.99989633, 0.99470447, 0.53302749, 0.4522403 , 0.27327062,
#        0.74804042, 0.90634889, 0.73288048, 0.61526969, 0.43081709,
#        0.86018956, 0.28276873, 0.37263772, 0.09141228, 0.90159082,
#        0.76077533, 0.07966326, 0.85048853, 0.2594719 , 0.0908614 ,
#        0.80929529, 0.06044254, 0.13181763, 0.4001362 , 0.56313574])

# %%
plt.plot(y)

# %%
x = np.linspace(0, 10, 50)

# %%
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
plt.plot(x, np.sin(x) + x)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
