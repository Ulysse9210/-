# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
l = np.array([3, -1, 5, 535, -23, 503, 24, -2])

# %%
l < 0
# Out:
# array([False,  True, False, False,  True, False, False,  True])

# %%
l[l<0]
# Out:
# array([ -1, -23,  -2])

# %%
x = np.linspace(-4, 6, 300)
y = np.sinc(x)

plt.plot(x, y)

# %%
plt.plot(x, y)
plt.plot(x[y>0], y[y>0], 'o')
