# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
plot([5, 10, 3, -1])

# %%
randn(10)
# Out:
# array([ 0.52043955, -0.05609222, -0.09762408, -1.1214957 , -1.57349844,
#         1.44014557,  0.21552698, -0.41628414,  0.07894184,  0.44794588])

# %%
plot(randn(50))

# %%
plot([1, 3, 1.5, 10], [5, 10, -5, 0])

# %% [markdown]
# alias python3='/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10'
